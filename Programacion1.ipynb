# %% [markdown]
# <a href="https://colab.research.google.com/github/Emmanuel-NM/Probabilidad-y-Estad-stica-/blob/main/Programacion1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# # Probabilidad Y Estadistica
#
# ## Unidad 1
# ## Grupo: **2Z**
#
# ### Practica 0. Introduccion a python
#
# Alumno: Emmanuel Noriega Morales
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas

# %%
a = 12
b = 25
if a > b:
    print(a,"es mayor que", b)
else:
    print(b,"es mayor que", a)
# Out:
# 25 es mayor que 12

# %%
for i in range(10):
  print(i)
  print("Hola", i)
  print("Fuera del for")
# Out:
# 0
# Hola 0
# Fuera del for
# 1
# Hola 1
# Fuera del for
# 2
# Hola 2
# Fuera del for
# 3
# Hola 3
# Fuera del for
# 4
# Hola 4
# Fuera del for
# 5
# Hola 5
# Fuera del for
# 6
# Hola 6
# Fuera del for
# 7
# Hola 7
# Fuera del for
# 8
# Hola 8
# Fuera del for
# 9
# Hola 9
# Fuera del for
